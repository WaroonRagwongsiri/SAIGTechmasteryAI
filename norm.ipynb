# %%
# !nvidia-smi
# Out:
# Sat Aug  9 20:50:27 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 565.77.01              Driver Version: 566.36         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060 ...    On  |   00000000:01:00.0 Off |                  N/A |
# | N/A   42C    P8              8W /   95W |    5802MiB /   6144MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A       298      G   /Xwayland                                   N/A      |
# |    0   N/A  N/A      1338      C   /python3.12                                 N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import os
from PIL import Image
from torchvision import transforms
from tqdm import tqdm

# %%
# Path to your images
image_dir = "competition/image"

# Transform to tensor only
to_tensor = transforms.ToTensor()

# Accumulators
mean = 0.0
std = 0.0
count = 0

# Loop through all images
for img_name in tqdm(os.listdir(image_dir)):
    if img_name.lower().endswith(('.png', '.jpg', '.jpeg')):
        img_path = os.path.join(image_dir, img_name)
        img = Image.open(img_path).convert("RGB")
        img_tensor = to_tensor(img)  # (C, H, W)

        count += 1
        mean += img_tensor.mean(dim=(1, 2))
        std += img_tensor.std(dim=(1, 2))

# Average over all images
mean /= count
std /= count

print(f"Mean: {mean}")
print(f"Std: {std}")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 7882/7882 [01:35<00:00, 82.61it/s]
# Mean: tensor([0.3812, 0.3990, 0.4013])
# Std: tensor([0.2665, 0.2686, 0.2547])
