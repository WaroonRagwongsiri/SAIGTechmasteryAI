# %%
# !nvidia-smi
# Out:
# Fri Aug  8 13:30:01 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 565.77.01              Driver Version: 566.36         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060 ...    On  |   00000000:01:00.0 Off |                  N/A |
# | N/A   41C    P8              9W /   95W |     144MiB /   6144MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A       374      G   /Xwayland                                   N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
from cleanvision import Imagelab

# %%
# Path to your dataset, you can specify your own dataset path
dataset_path = "./competition/image"

# Initialize imagelab with your dataset
imagelab = Imagelab(data_path=dataset_path)

# Find issues
imagelab.find_issues()
# Out:
# Reading images from /mnt/d/First Year/SAIGTechmastery/PracticeAI/competition/image
# Checking for dark, light, odd_aspect_ratio, low_information, exact_duplicates, near_duplicates, blurry, grayscale, odd_size images ...
#   0%|          | 0/7882 [00:00<?, ?it/s]
#   0%|          | 0/7882 [00:00<?, ?it/s]
# Issue checks completed. 3400 issues found in the dataset. To see a detailed report of issues found, use imagelab.report().

# %%
imagelab.report()
# Out:
# Issues found in images in order of severity in the dataset
#
# |    | issue_type       |   num_images |
# |---:|:-----------------|-------------:|
# |  0 | odd_size         |         2284 |
# |  1 | odd_aspect_ratio |          776 |
# |  2 | low_information  |          255 |
# |  3 | blurry           |           47 |
# |  4 | dark             |           38 |
# |  5 | light            |            0 |
# |  6 | grayscale        |            0 |
# |  7 | exact_duplicates |            0 |
# |  8 | near_duplicates  |            0 |
#
# --------------------- odd_size images ----------------------
#
# Number of examples with this issue: 2284
# Examples representing most severe instances of this issue:
# ----------------- odd_aspect_ratio images ------------------
#
# Number of examples with this issue: 776
# Examples representing most severe instances of this issue:
# ------------------ low_information images ------------------
#
# Number of examples with this issue: 255
# Examples representing most severe instances of this issue:
# ---------------------- blurry images -----------------------
#
# Number of examples with this issue: 47
# Examples representing most severe instances of this issue:
# ----------------------- dark images ------------------------
#
# Number of examples with this issue: 38
# Examples representing most severe instances of this issue:
